# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([0,1,2,3,4,5,6])
Y = np.array([2.4,2.1,3.2,5.6,9.3,14.6,21.9])

# %%
w0 = 2.5095
w1 = -1.2
w2 = 0.733

# %%
Y_pred = w0 + w1*X + w2*np.multiply(X,X)

# %%
plt.plot(X,Y_pred)
plt.scatter(X,Y)
