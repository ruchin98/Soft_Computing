# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import timeit

# %%
df = pd.read_csv('Housing.csv', index_col='Unnamed: 0')
df.head()
# Out:
#      price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 1  42000.0     5850         3        1        2      yes      no      yes
# 2  38500.0     4000         2        1        1      yes      no       no
# 3  49500.0     3060         3        1        1      yes      no       no
# 4  60500.0     6650         3        1        2      yes     yes       no
# 5  61000.0     6360         2        1        1      yes      no       no
#
#   gashw airco  garagepl prefarea
# 1    no    no         1       no
# 2    no    no         0       no
# 3    no    no         0       no
# 4    no    no         0       no
# 5    no    no         0       no

# %%
df.shape
# Out:
# (546, 12)

# %%
df.describe(include='all')
# Out:
#                 price       lotsize    bedrooms     bathrms     stories  \
# count      546.000000    546.000000  546.000000  546.000000  546.000000
# unique            NaN           NaN         NaN         NaN         NaN
# top               NaN           NaN         NaN         NaN         NaN
# freq              NaN           NaN         NaN         NaN         NaN
# mean     68121.597070   5150.265568    2.965201    1.285714    1.807692
# std      26702.670926   2168.158725    0.737388    0.502158    0.868203
# min      25000.000000   1650.000000    1.000000    1.000000    1.000000
# 25%      49125.000000   3600.000000    2.000000    1.000000    1.000000
# 50%      62000.000000   4600.000000    3.000000    1.000000    2.000000
# 75%      82000.000000   6360.000000    3.000000    2.000000    2.000000
# max     190000.000000  16200.000000    6.000000    4.000000    4.000000
#
#        driveway recroom fullbase gashw airco    garagepl prefarea
# ...

# %%
df.corr()
# Out:
#              price   lotsize  bedrooms   bathrms   stories  garagepl
# price     1.000000  0.535796  0.366447  0.516719  0.421190  0.383302
# lotsize   0.535796  1.000000  0.151851  0.193833  0.083675  0.352872
# bedrooms  0.366447  0.151851  1.000000  0.373769  0.407974  0.139117
# bathrms   0.516719  0.193833  0.373769  1.000000  0.324066  0.178178
# stories   0.421190  0.083675  0.407974  0.324066  1.000000  0.043412
# garagepl  0.383302  0.352872  0.139117  0.178178  0.043412  1.000000

# %%
df.driveway = df.driveway.eq('yes').mul(1)
df.recroom = df.recroom.eq('yes').mul(1)
df.fullbase = df.fullbase.eq('yes').mul(1)
df.gashw = df.gashw.eq('yes').mul(1)
df.airco = df.airco.eq('yes').mul(1)
df.prefarea = df.prefarea.eq('yes').mul(1)

# %%
df.head()
# Out:
#      price  lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase  \
# 1  42000.0     5850         3        1        2         1        0         1
# 2  38500.0     4000         2        1        1         1        0         0
# 3  49500.0     3060         3        1        1         1        0         0
# 4  60500.0     6650         3        1        2         1        1         0
# 5  61000.0     6360         2        1        1         1        0         0
#
#    gashw  airco  garagepl  prefarea
# 1      0      0         1         0
# 2      0      0         0         0
# 3      0      0         0         0
# 4      0      0         0         0
# 5      0      0         0         0

# %%
def radial_kernel(x0, X, tau):
    return np.exp(np.sum((X - x0) ** 2, axis=1) / (-2 * tau * tau))

# %%
def local_regression(x0, X, Y, tau):
    #print("inside local")
    xr = radial_kernel(x0,X,tau)
    #print("CC")
    xw = (X.T)*xr
    #print("EE")
    w = np.linalg.pinv(xw @ X) @ xw @ Y
    #print("DD")
    return x0*w

# %%
X = df[['lotsize']] #,'bedrooms','bathrms'
Y = df['price']
def plot_lwr(tau):
    # prediction
    #print("AA")
    domain = np.linspace(1000, 20000, num=415)
    prediction = [local_regression(x0, X, Y, tau) for x0 in domain]
    #print("BB")
    #plot = plt.figure(plt_width=400, plt_height=400)
    plt.rcParams["figure.figsize"] = [13,5]
    plt.title.text = 'tau=%g' % tau
    #plt.scatter(X, Y, alpha=.3)
    plt.plot(domain, prediction,X,Y,'rx')
    
    
    return prediction

# %%
pred = plot_lwr(20)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in matmul
#   import sys

# %% [markdown]
# Plot for tau = 20

# %%
print(y.shape[0])
print(y[1])
print(pred[1]['lotsize'])
print(pred[1]['lotsize'] - y[1])
# Out:
# 546
# -0.9782391110682289
# 28524.37417654809
# 28525.35241565916

# %%
l = y.shape[0]
score=0
for i in range(l):
    score = score + (pred[i]['lotsize'] - y[i])*(pred[i]['lotsize'] - y[i])
score
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-114-8d440cb0b7d4> in <module>
#       2 score=0
#       3 for i in range(l):
# ----> 4     score = score + (pred[i]['lotsize'] - y[i])*(pred[i]['lotsize'] - y[i])
#       5 score
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
# ...

# %%
plot_lwr(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in matmul
#   import sys
# <module 'matplotlib.pyplot' from '/home/ruchin/.local/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Plot for tau = 5

# %%
plot_lwr(0.5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in matmul
#   import sys
# <module 'matplotlib.pyplot' from '/home/ruchin/.local/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Plot for tau = 0.5(small value)

# %% [markdown]
# As we can see if tau is very small than their will be overfitting of the data.
